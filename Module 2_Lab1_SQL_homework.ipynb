# %%
#!python -m install sqlalchemy==1.3.9
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\python.exe: No module named install

# %% [markdown]
# Connect to the database
# Let us first load the SQL extension and establish a connection with the database

# %%
#!python -m install ipython-sql
#!python -m install prettytable
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\python.exe: No module named install
# c:\Users\user\AppData\Local\Programs\Python\Python313\python.exe: No module named install

# %%
#pip install sqlalchemy==1.3.9
# %pip install sqlalchemy>=1.4.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
#%reload_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
pip install -q pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %%
#DROP THE TABLE IF EXISTS
# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# Tasks
# Now write and execute SQL queries to solve the assignment tasks.
# Note: If the column names are in mixed case enclose it in double quotes For Example "Landing_Outcome"

# %%
sql_qq = """
SELECT DISTINCT "Launch_Site"
FROM SPACEXTABLE;
"""

# %%
#Read sql table - Task 1
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df22 = pd.read_sql(sql_qq, con=engine)
raw_df22
# Out:
#     Launch_Site
# 0   CCAFS LC-40
# 1   VAFB SLC-4E
# 2    KSC LC-39A
# 3  CCAFS SLC-40

# %%
#Read sql table
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df = pd.read_sql("SELECT * FROM SPACEXTABLE", con=engine)
raw_df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
#Task 1 -Display the names of the unique launch sites in the space mission
'''SELECT DISTINCT "Launch_Site"
FROM SPACEXTABLE;
'''

# %%
#Task 2 - Display 5 records where launch sites begin with the string 'CCA'
'''SELECT *
FROM SPACEXTABLE
WHERE "Launch_Site" LIKE 'CCA%'
LIMIT 5;
'''

# %%
sql_q2 = """
SELECT *
FROM SPACEXTABLE
WHERE "Launch_Site" LIKE 'CCA%'
LIMIT 5;
"""

# %%
#Read sql table - Task 2
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df2 = pd.read_sql(sql_q2, con=engine)
raw_df2
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
#Task 3 - Display the total payload mass carried by boosters launched by NASA (CRS)
'''SELECT SUM("Payload_Mass__kg_") AS "Total_Payload_Mass"
FROM SPACEXTABLE
WHERE "Customer" = 'NASA (CRS)';
'''

# %%
sql_q3 = """
SELECT SUM("Payload_Mass__kg_") AS "Total_Payload_Mass"
FROM SPACEXTABLE
WHERE "Customer" = 'NASA (CRS)';
"""

# %%
#Read sql table - Task 3
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df3 = pd.read_sql(sql_q3, con=engine)
raw_df3
# Out:
#    Total_Payload_Mass
# 0               45596

# %%
#Task 4 - Display average payload mass carried by booster version F9 v1.1
'''SELECT AVG("Payload_Mass__kg_") AS "Average_Payload_Mass"
FROM SPACEXTABLE
WHERE "Booster_Version" = 'F9 v1.1';
'''

# %%
sql_q4 = """
SELECT AVG("Payload_Mass__kg_") AS "Average_Payload_Mass"
FROM SPACEXTABLE
WHERE "Booster_Version" = 'F9 v1.1';
"""

# %%
#Read sql table - Task 4
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df4 = pd.read_sql(sql_q4, con=engine)
raw_df4
# Out:
#    Average_Payload_Mass
# 0                2928.4

# %%
#Task 5
#List the date when the first succesful landing outcome in ground pad was acheived.
#Hint:Use min function
'''SELECT MIN("Date") AS "First_Successful_Ground_Pad_Landing"
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (ground pad)';
'''

# %%
sql_q5 = """
SELECT MIN("Date") AS "First_Successful_Ground_Pad_Landing"
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (ground pad)';
"""

# %%
#Read sql table - Task 5
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df5 = pd.read_sql(sql_q5, con=engine)
raw_df5
# Out:
#   First_Successful_Ground_Pad_Landing
# 0                          2015-12-22

# %%
#Task 6
#List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000
'''SELECT DISTINCT "Booster_Version"
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (drone ship)'
  AND "Payload_Mass__kg_" > 4000
  AND "Payload_Mass__kg_" < 6000;
'''

# %%
sql_q6 = """
SELECT DISTINCT "Booster_Version"
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (drone ship)'
  AND "Payload_Mass__kg_" > 4000
  AND "Payload_Mass__kg_" < 6000;
"""

# %%
#Read sql table - Task 6
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df6 = pd.read_sql(sql_q6, con=engine)
raw_df6
# Out:
#   Booster_Version
# 0     F9 FT B1022
# 1     F9 FT B1026
# 2  F9 FT  B1021.2
# 3  F9 FT  B1031.2

# %%
#Task 7
#List the total number of successful and failure mission outcomes
'''SELECT "Mission_Outcome", COUNT(*) AS "Total_Count"
FROM SPACEXTABLE
GROUP BY "Mission_Outcome";
'''

# %%
sql_q7 = """
SELECT "Mission_Outcome", COUNT(*) AS "Total_Count"
FROM SPACEXTABLE
GROUP BY "Mission_Outcome";
"""

# %%
#Read sql table - Task 7
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df7 = pd.read_sql(sql_q7, con=engine)
raw_df7
# Out:
#                     Mission_Outcome  Total_Count
# 0               Failure (in flight)            1
# 1                           Success           98
# 2                          Success             1
# 3  Success (payload status unclear)            1

# %%
#Task 8
#List all the booster_versions that have carried the maximum payload mass, using a subquery with a suitable aggregate function.
'''SELECT DISTINCT "Booster_Version"
FROM SPACEXTABLE
WHERE "Payload_Mass__kg_" = (
    SELECT MAX("Payload_Mass__kg_")
    FROM SPACEXTABLE
);
'''

# %%
sql_q8 = """
SELECT DISTINCT "Booster_Version"
FROM SPACEXTABLE
WHERE "Payload_Mass__kg_" = (
    SELECT MAX("Payload_Mass__kg_")
    FROM SPACEXTABLE
);
"""

# %%
#Read sql table - Task 8
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df8 = pd.read_sql(sql_q8, con=engine)
raw_df8
# Out:
#    Booster_Version
# 0    F9 B5 B1048.4
# 1    F9 B5 B1049.4
# 2    F9 B5 B1051.3
# 3    F9 B5 B1056.4
# 4    F9 B5 B1048.5
# 5    F9 B5 B1051.4
# 6    F9 B5 B1049.5
# 7   F9 B5 B1060.2
# 8   F9 B5 B1058.3
# 9    F9 B5 B1051.6
# 10   F9 B5 B1060.3
# 11  F9 B5 B1049.7

# %% [markdown]
# Task 9
# List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
# Note: SQLLite does not support monthnames. So you need to use substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.

# %%
#Task 9
'''SELECT 
  substr("Date", 6, 2) AS "Month",
  "Landing_Outcome",
  "Booster_Version",
  "Launch_Site"
FROM SPACEXTABLE
WHERE "Landing_Outcome" LIKE '%Failure (drone ship)%'
  AND substr("Date", 0, 5) = '2015';
'''

# %%
sql_q9 = """
SELECT 
  substr("Date", 6, 2) AS "Month",
  "Landing_Outcome",
  "Booster_Version",
  "Launch_Site"
FROM SPACEXTABLE
WHERE "Landing_Outcome" LIKE '%Failure (drone ship)%'
  AND substr("Date", 0, 5) = '2015';
"""

# %%
#Read sql table - Task 9
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df9 = pd.read_sql(sql_q9, con=engine)
raw_df9
# Out:
#   Month       Landing_Outcome Booster_Version  Launch_Site
# 0    01  Failure (drone ship)   F9 v1.1 B1012  CCAFS LC-40
# 1    04  Failure (drone ship)   F9 v1.1 B1015  CCAFS LC-40

# %% [markdown]
# Task 10
# Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
#Task 10
'''SELECT "Landing_Outcome", COUNT(*) AS "Outcome_Count"
FROM SPACEXTABLE
WHERE "Date" BETWEEN '2010-06-04' AND '2017-03-20'
GROUP BY "Landing_Outcome"
ORDER BY "Outcome_Count" DESC;
'''

# %%
sql_q10 = """
SELECT "Landing_Outcome", COUNT(*) AS "Outcome_Count"
FROM SPACEXTABLE
WHERE "Date" BETWEEN '2010-06-04' AND '2017-03-20'
GROUP BY "Landing_Outcome"
ORDER BY "Outcome_Count" DESC;
"""

# %%
#Read sql table - Task 10
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///my_data1.db")
raw_df10 = pd.read_sql(sql_q10, con=engine)
raw_df10
# Out:
#           Landing_Outcome  Outcome_Count
# 0              No attempt             10
# 1    Success (drone ship)              5
# 2    Failure (drone ship)              5
# 3    Success (ground pad)              3
# 4      Controlled (ocean)              3
# 5    Uncontrolled (ocean)              2
# 6     Failure (parachute)              2
# 7  Precluded (drone ship)              1

# %%
#pip install --upgrade pandas sqlalchemy
# Out:
# ...
#   Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.0 MB 16.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 17.5 MB/s  0:00:00
# Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
# ...
#
#   Attempting uninstall: sqlalchemy
#
#     Found existing installation: SQLAlchemy 1.3.9
#
#     Uninstalling SQLAlchemy-1.3.9:
#
#       Successfully uninstalled SQLAlchemy-1.3.9
#
#    ---------------------------------------- 0/2 [sqlalchemy]
#    ---------------------------------------- 0/2 [sqlalchemy]
#    ---------------------------------------- 0/2 [sqlalchemy]
#    ---------------------------------------- 0/2 [sqlalchemy]
# ...

# %%
#Check library version
import pandas as pd
import sqlalchemy

print("Pandas version:", pd.__version__)
print("SQLAlchemy version:", sqlalchemy.__version__)
# Out:
# Pandas version: 2.3.1
# SQLAlchemy version: 1.3.9

# %%
pip install --upgrade sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Replace 'SPACEXTABLE' with your actual table name
raw_df = pd.read_sql("SELECT * FROM SPACEXTABLE", con=engine)
#raw_df=pd.read_sql(sql_q,engine)

# Preview the data
raw_df.head()

# %%
raw_df=pd.read_sql(sql_q,engine)
